# %%
import pandas as pd

# %%
data=pd.read_csv('heartrate_seconds_merged(1).csv',index_col=0)

# %%
data
# Out:
#                             Time  Value
# Id
# 2022484408  4/12/2016 7:21:00 AM     97
# 2022484408  4/12/2016 7:21:05 AM    102
# 2022484408  4/12/2016 7:21:10 AM    105
# 2022484408  4/12/2016 7:21:20 AM    103
# 2022484408  4/12/2016 7:21:25 AM    101
# ...                          ...    ...
# 8877689391  5/12/2016 2:43:53 PM     57
# 8877689391  5/12/2016 2:43:58 PM     56
# 8877689391  5/12/2016 2:44:03 PM     55
# 8877689391  5/12/2016 2:44:18 PM     55
# 8877689391  5/12/2016 2:44:28 PM     56
#
# [2483658 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2483658 entries, 2022484408 to 8877689391
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Time    object
#  1   Value   int64
# dtypes: int64(1), object(1)
# memory usage: 56.8+ MB

# %%
data.isna().sum()
# Out:
# Time     0
# Value    0
# dtype: int64

# %%
data['Time'] = pd.to_datetime(data['Time'])
data['date'] = data['Time'].dt.date
data['time'] = data['Time'].dt.time
data = data.drop('Time', axis=1)

# %%
data.head(5)
# Out:
#             Value        date      time
# Id
# 2022484408     97  2016-04-12  07:21:00
# 2022484408    102  2016-04-12  07:21:05
# 2022484408    105  2016-04-12  07:21:10
# 2022484408    103  2016-04-12  07:21:20
# 2022484408    101  2016-04-12  07:21:25

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.pairplot( data=data)
plt.show()

# %%
sns.lineplot(x='Value', y='Id', data=data)
plt.show()

# %%
data.columns
# Out:
# Index(['Value', 'date', 'time'], dtype='object')

# %%
sns.jointplot(x='Value', y='Id', data=data)
plt.show()

# %%
data.to_csv('C:/Users/RAKSHITHA/Desktop/final_heart_rate_week8.csv', index=False)
