# %%
import pandas as pd

# %%
data=pd.read_csv('weightLogInfo_merged.csv ',index_col=0)

# %%
data
# Out:
#                              Date    WeightKg  WeightPounds   Fat        BMI  \
# Id
# 1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0  22.650000
# 1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN  22.650000
# 1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN  47.540001
# 2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN  21.450001
# 2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN  21.690001
# ...                           ...         ...           ...   ...        ...
# 8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN  25.440001
# 8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN  25.559999
# 8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN  25.610001
# 8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN  25.559999
# 8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN  25.139999
#
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['date'] = data['Date'].dt.date
data['time'] = data['Date'].dt.time
data = data.drop('Date', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 1503960366 to 8877689391
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   WeightKg        67 non-null     float64
#  1   WeightPounds    67 non-null     float64
#  2   Fat             2 non-null      float64
#  3   BMI             67 non-null     float64
#  4   IsManualReport  67 non-null     bool
#  5   LogId           67 non-null     int64
#  6   date            67 non-null     object
#  7   time            67 non-null     object
# dtypes: bool(1), float64(4), int64(1), object(2)
# memory usage: 4.3+ KB

# %%
data.head()
# Out:
#               WeightKg  WeightPounds   Fat        BMI  IsManualReport  \
# Id
# 1503960366   52.599998    115.963147  22.0  22.650000            True
# 1503960366   52.599998    115.963147   NaN  22.650000            True
# 1927972279  133.500000    294.317120   NaN  47.540001           False
# 2873212765   56.700001    125.002104   NaN  21.450001            True
# 2873212765   57.299999    126.324875   NaN  21.690001            True
#
#                     LogId        date      time
# Id
# 1503960366  1462233599000  2016-05-02  23:59:59
# 1503960366  1462319999000  2016-05-03  23:59:59
# 1927972279  1460509732000  2016-04-13  01:08:52
# 2873212765  1461283199000  2016-04-21  23:59:59
# 2873212765  1463097599000  2016-05-12  23:59:59

# %%
data.isna().sum()
# Out:
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# date               0
# time               0
# dtype: int64

# %%
data['WeightPounds']=data['WeightPounds'].apply(lambda x: round(x, 1))

# %%
data['WeightPounds']
# Out:
# Id
# 1503960366    116.0
# 1503960366    116.0
# 1927972279    294.3
# 2873212765    125.0
# 2873212765    126.3
#               ...
# 8877689391    187.4
# 8877689391    188.3
# 8877689391    188.5
# 8877689391    188.3
# 8877689391    185.2
# Name: WeightPounds, Length: 67, dtype: float64

# %%
data['Fat'].isna().sum()
# Out:
# 65

# %%
data['Fat'].fillna(value=0, inplace=True)

# %%
data['Fat'].unique()
# Out:
# array([22.,  0., 25.])

# %%
data['BMI']=data['BMI'].apply(lambda x: round(x, 1))

# %%
data['BMI']
# Out:
# Id
# 1503960366    22.6
# 1503960366    22.6
# 1927972279    47.5
# 2873212765    21.5
# 2873212765    21.7
#               ...
# 8877689391    25.4
# 8877689391    25.6
# 8877689391    25.6
# 8877689391    25.6
# 8877689391    25.1
# Name: BMI, Length: 67, dtype: float64

# %%
data['WeightKg']=data['WeightKg'].apply(lambda x: round(x, 1))

# %%
data['WeightKg']
# Out:
# Id
# 1503960366     52.6
# 1503960366     52.6
# 1927972279    133.5
# 2873212765     56.7
# 2873212765     57.3
#               ...
# 8877689391     85.0
# 8877689391     85.4
# 8877689391     85.5
# 8877689391     85.4
# 8877689391     84.0
# Name: WeightKg, Length: 67, dtype: float64

# %%
data['IsManualReport'].unique()
# Out:
# array([ True, False])

# %%
data.head(4)
# Out:
#             WeightKg  WeightPounds   Fat   BMI  IsManualReport          LogId  \
# Id
# 1503960366      52.6         116.0  22.0  22.6            True  1462233599000
# 1503960366      52.6         116.0   0.0  22.6            True  1462319999000
# 1927972279     133.5         294.3   0.0  47.5           False  1460509732000
# 2873212765      56.7         125.0   0.0  21.5            True  1461283199000
#
#                   date      time
# Id
# 1503960366  2016-05-02  23:59:59
# 1503960366  2016-05-03  23:59:59
# 1927972279  2016-04-13  01:08:52
# 2873212765  2016-04-21  23:59:59

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.pairplot( data=data)
plt.show()
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.lineplot(x='WeightKg', y='Id', data=data)
plt.show()

# %%
sns.boxplot(x='WeightPounds', data=data)
plt.show()

# %%
sns.displot(x='BMI', y='Id', data=data)
plt.show()

# %%
g = sns.lmplot(
data=data,
    x="Fat", y="BMI", hue="WeightKg",
    height=5
)
