# %%
import pandas as pd

# %%
data=pd.read_csv('sleepDay_merged.csv',index_col=0)

# %%
data
# Out:
#                          SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# Id
# 1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1503960366  4/13/2016 12:00:00 AM                  2                 384
# 1503960366  4/15/2016 12:00:00 AM                  1                 412
# 1503960366  4/16/2016 12:00:00 AM                  2                 340
# 1503960366  4/17/2016 12:00:00 AM                  1                 700
# ...                           ...                ...                 ...
# 8792009665  4/30/2016 12:00:00 AM                  1                 343
# 8792009665   5/1/2016 12:00:00 AM                  1                 503
# 8792009665   5/2/2016 12:00:00 AM                  1                 415
# 8792009665   5/3/2016 12:00:00 AM                  1                 516
# 8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#             TotalTimeInBed
# Id
# 1503960366             346
# ...

# %%
data['SleepDay'] = pd.to_datetime(data['SleepDay'])
data['date'] = data['SleepDay'].dt.date
data['time'] = data['SleepDay'].dt.time
data = data.drop('SleepDay', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413 entries, 1503960366 to 8792009665
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TotalSleepRecords   413 non-null    int64
#  1   TotalMinutesAsleep  413 non-null    int64
#  2   TotalTimeInBed      413 non-null    int64
#  3   date                413 non-null    object
#  4   time                413 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 19.4+ KB

# %%
data.isna().sum()
# Out:
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# date                  0
# time                  0
# dtype: int64

# %%
data.head(5)
# Out:
#             TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed        date  \
# Id
# 1503960366                  1                 327             346  2016-04-12
# 1503960366                  2                 384             407  2016-04-13
# 1503960366                  1                 412             442  2016-04-15
# 1503960366                  2                 340             367  2016-04-16
# 1503960366                  1                 700             712  2016-04-17
#
#                 time
# Id
# 1503960366  00:00:00
# 1503960366  00:00:00
# 1503960366  00:00:00
# 1503960366  00:00:00
# 1503960366  00:00:00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.hist(data['TotalSleepRecords'])
# Out:
# (array([367.,   0.,   0.,   0.,   0.,  43.,   0.,   0.,   0.,   3.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
sns.pairplot( data=data)
plt.show()

# %%
sns.lineplot(x='TotalMinutesAsleep', y='Id', data=data)
plt.show()

# %%
sns.displot(x='TotalMinutesAsleep', y='Id', data=data)
plt.show()
