# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("chipotle.tsv",sep='\t')
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
data.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
data= data.rename(columns={'item_price':'item_Price'})
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_Price
# 0                                                   NaN     $2.39
# ...

# %%
data.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_Price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_Price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.tail(20)
# Out:
#       order_id  quantity            item_name  \
# 4602      1827         1     Barbacoa Burrito
# 4603      1827         1     Barbacoa Burrito
# 4604      1828         1         Chicken Bowl
# 4605      1828         1  Chips and Guacamole
# 4606      1828         1    Canned Soft Drink
# 4607      1829         1        Steak Burrito
# 4608      1829         1       Veggie Burrito
# 4609      1829         1    Canned Soft Drink
# 4610      1830         1        Steak Burrito
# 4611      1830         1       Veggie Burrito
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# ...

# %%
data.order_id.isnull().sum()
# Out:
# 0

# %%
data.order_id.mode()
# Out:
# 0    926
# Name: order_id, dtype: int64

# %%
data['order_id']=data.order_id.fillna(926)
data['order_id']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#         ...
# 4617    1833
# 4618    1833
# 4619    1834
# 4620    1834
# 4621    1834
# Name: order_id, Length: 4622, dtype: int64

# %%
data.order_id.isnull().sum()
# Out:
# 0

# %%
data.quantity.isnull().sum()
# Out:
# 0

# %%
data.item_name.isnull().sum()
# Out:
# 0

# %%
data.choice_description.isnull().sum()
# Out:
# 1246

# %%
data.choice_description.mode()
# Out:
# 0    [Diet Coke]
# Name: choice_description, dtype: object

# %%
data['choice_description']=data.choice_description.fillna('Diet Coke')
data['choice_description']
# Out:
# 0                                               Diet Coke
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                               Diet Coke
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
data.choice_description.isnull().sum()
# Out:
# 0

# %%
data.item_Price.isnull().sum()
# Out:
# 0

# %%
data['item_Price'] = data['item_Price'].str.replace('$', '')
data['item_Price']
# Out:
# C:\Users\RAKSHITHA\AppData\Local\Temp\ipykernel_12476\1687139258.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['item_Price'] = data['item_Price'].str.replace('$', '')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_Price, Length: 4622, dtype: object

# %%
data['item_Price'] = data['item_Price'].fillna(0)
data['item_Price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_Price, Length: 4622, dtype: object

# %%
data1=data['item_name'].values
data1
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar', ...,
#        'Chicken Salad Bowl', 'Chicken Salad Bowl', 'Chicken Salad Bowl'],
#       dtype=object)

# %%
data2=data['item_name'].count()
data2
# Out:
# 4622

# %%
total_price = data.item_Price.mode()
total_price
# Out:
# 0    8.75
# Name: item_Price, dtype: object

# %%
item_quantities = data.groupby('item_name')['quantity'].sum()
item_quantities
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
most_ordered_item = data.groupby('item_name')['quantity'].sum().idxmax()
most_ordered_item
# Out:
# 'Chicken Bowl'

# %%
total_ordered_count = data['quantity'].sum()
total_ordered_count
# Out:
# 4972

# %%
data['revenue'] = data['quantity'] * data['item_Price']
total_revenue = data['revenue'].sum()
total_revenue
# Out:
# '2.39 3.39 3.39 2.39 16.98 16.98 10.98 1.69 11.75 9.25 9.25 4.45 8.75 8.75 11.25 4.45 2.39 8.49 8.49 2.18 2.18 8.75 4.45 8.99 3.39 10.98 3.39 2.39 8.49 8.99 1.09 8.49 2.39 8.99 1.69 8.99 1.09 8.75 8.75 4.45 2.95 11.75 2.15 4.45 11.25 11.75 8.75 10.98 8.99 3.39 8.99 3.99 8.99 2.18 2.18 10.98 1.09 8.99 2.39 9.25 11.25 11.75 2.15 4.45 9.25 11.25 8.75 8.99 8.99 3.39 8.99 10.98 8.99 1.69 8.99 3.99 8.75 4.45 8.75 8.75 2.15 8.75 11.25 2.15 9.25 8.75 8.75 9.25 8.49 8.99 1.09 9.25 2.95 11.75 11.75 9.25 11.75 4.45 9.25 4.45 11.75 8.75 8.75 4.45 8.99 8.99 3.99 8.49 3.39 8.99 1.09 9.25 4.45 8.75 2.95 4.45 2.39 8.49 8.99 8.49 1.09 8.99 3.99 8.75 9.25 4.45 11.25 4.45 8.99 1.09 9.25 2.95 4.45 11.75 4.45 8.49 2.39 10.98 22.50 22.50 11.75 4.45 11.25 4.45 11.25 4.45 11.25 11.25 11.75 9.25 4.45 11.48 17.98 17.98 1.69 17.50 17.50 4.45 8.49 2.39 17.50 17.50 4.45 4.45 11.25 11.75 10.98 8.49 10.98 2.18 2.18 11.48 8.49 2.39 4.45 11.25 11.75 8.75 8.49 2.18 2.18 8.49 3.39 8.49 8.99 10.98 11.48 8.49 1.09 1.09 
# ...

# %%
item_revenue = data.groupby('item_Price')['revenue'].sum()
item_revenue
# Out:
# item_Price
# 1.09     1.09 1.09 1.09 1.09 1.09 1.09 1.09 1.09 1.09 1...
# 1.25     1.25 1.25 1.25 1.25 1.25 1.25 1.25 1.25 1.25 1...
# 1.50     1.50 1.50 1.50 1.50 1.50 1.50 1.50 1.50 1.50 1...
# 1.69     1.69 1.69 1.69 1.69 1.69 1.69 1.69 1.69 1.69 1...
# 1.99                                                 1.99
#                                ...
# 8.75     8.75 8.75 8.75 8.75 8.75 8.75 8.75 8.75 8.75 8...
# 8.90     8.90 8.90 8.90 8.90 8.90 8.90 8.90 8.90 8.90 8...
# 8.99     8.99 8.99 8.99 8.99 8.99 8.99 8.99 8.99 8.99 8...
# 9.25     9.25 9.25 9.25 9.25 9.25 9.25 9.25 9.25 9.25 9...
# 9.39     9.39 9.39 9.39 9.39 9.39 9.39 9.39 9.39 9.39 9...
# Name: revenue, Length: 78, dtype: object

# %%
no_of_orders=data.shape[0]
no_of_orders
# Out:
# 4622

# %%
unique_values = data['item_name'].unique()
unique_values
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
total_cost_per_item = data.groupby('item_name')['item_price'].sum()
total_cost_per_item
# Out:
# item_name
# 6 Pack Soft Drink                        6.49 6.49 6.49 6.49 6.49 6.49 6.49 6.49 6.49 6...
# Barbacoa Bowl                            11.75 11.75 9.25 8.99 9.25 11.75 9.25 9.25 9.2...
# Barbacoa Burrito                         8.99 9.25 9.25 11.75 11.75 9.25 8.99 11.75 11....
# Barbacoa Crispy Tacos                    11.75 9.25 11.48 11.75 9.25 9.25 8.99 9.25 18....
# Barbacoa Salad Bowl                      11.89 11.89 9.39 9.39 9.39 11.89 11.89 9.39 11...
# Barbacoa Soft Tacos                      9.25 9.25 8.99 9.25 9.25 11.75 11.75 9.25 9.25...
# Bottled Water                            1.09 1.09 1.09 1.50 1.50 1.50 3.00 1.50 1.50 1...
# Bowl                                                                           22.20 7.40
# Burrito                                                     7.40 7.40 7.40 7.40 7.40 7.40
# Canned Soda                              2.18 1.09 2.18 1.09 1.09 1.09 1.09 2.18 2.18 1...
# ...

# %%
total_quantity_per_item = data.groupby('item_name')['quantity'].sum()
total_quantity_per_item
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
total_per_item = data.groupby('item_name').agg({'item_price': 'sum', 'quantity': 'sum'})
total_per_item
# Out:
#                                                                               item_price  \
# item_name
# 6 Pack Soft Drink                      6.49 6.49 6.49 6.49 6.49 6.49 6.49 6.49 6.49 6...
# Barbacoa Bowl                          11.75 11.75 9.25 8.99 9.25 11.75 9.25 9.25 9.2...
# Barbacoa Burrito                       8.99 9.25 9.25 11.75 11.75 9.25 8.99 11.75 11....
# Barbacoa Crispy Tacos                  11.75 9.25 11.48 11.75 9.25 9.25 8.99 9.25 18....
# Barbacoa Salad Bowl                    11.89 11.89 9.39 9.39 9.39 11.89 11.89 9.39 11...
# Barbacoa Soft Tacos                    9.25 9.25 8.99 9.25 9.25 11.75 11.75 9.25 9.25...
# Bottled Water                          1.09 1.09 1.09 1.50 1.50 1.50 3.00 1.50 1.50 1...
# Bowl                                                                         22.20 7.40
# Burrito                                                   7.40 7.40 7.40 7.40 7.40 7.40
# ...

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_Price item_price  \
# 0                                          Diet Coke      2.39       2.39
# 1                                       [Clementine]      3.39       3.39
# 2                                            [Apple]      3.39       3.39
# 3                                          Diet Coke      2.39       2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98      16.98
#
#         revenue
# 0         2.39
# 1         3.39
# 2         3.39
# 3         2.39
# 4  16.98 16.98
