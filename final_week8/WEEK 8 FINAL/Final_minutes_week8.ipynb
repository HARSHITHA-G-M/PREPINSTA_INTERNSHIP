# %%
import pandas as pd

# %%
data1=pd.read_csv('cleaned_minutes_intensity_new.csv',index_col=0)

# %%
data1
# Out:
#             Intensity00  Intensity01  Intensity02  Intensity03  Intensity04  \
# Id
# 1503960366            1            1            0            0            0
# 1503960366            0            0            0            0            0
# 1503960366            0            0            0            0            0
# 1503960366            0            0            0            0            0
# 1503960366            0            0            0            0            0
# ...                 ...          ...          ...          ...          ...
# 8877689391            0            0            0            0            0
# 8877689391            0            0            0            0            0
# 8877689391            0            0            0            0            0
# 8877689391            0            0            0            0            0
# 8877689391            1            1            1            0            1
#
# ...

# %%
data3=pd.read_csv('cleaned_minutes_sleep_new.csv',index_col=0)

# %%
data3
# Out:
#             Calories00  Calories01  Calories02  Calories03  Calories04  \
# Id
# 1503960366      1.8876      2.2022      0.9438      0.9438      0.9438
# 1503960366      0.7865      0.7865      0.7865      0.7865      0.9438
# 1503960366      0.7865      0.7865      0.7865      0.7865      0.7865
# 1503960366      0.7865      0.7865      0.7865      0.7865      0.7865
# 1503960366      0.7865      0.7865      0.7865      0.7865      0.7865
# ...                ...         ...         ...         ...         ...
# 8877689391      1.2170      1.2170      1.2170      1.2170      1.2170
# 8877689391      1.2170      1.2170      1.2170      1.2170      1.2170
# 8877689391      1.2170      1.2170      1.2170      1.2170      1.2170
# 8877689391      1.2170      1.2170      1.2170      1.2170      1.2170
# 8877689391      4.6246      4.1378      4.3812      1.8255      3.1642
#
#             Calories05  Calories06  Calories07  Calories08  Calories09  ...  \
# ...

# %%
data4=pd.read_csv('cleaned_minutes_slep_new.csv',index_col=0)

# %%
data4
# Out:
#                   date  value        logId
# Id
# 1503960366  2016-04-12      3  11380564589
# 1503960366  2016-04-12      2  11380564589
# 1503960366  2016-04-12      1  11380564589
# 1503960366  2016-04-12      1  11380564589
# 1503960366  2016-04-12      1  11380564589
# ...                ...    ...          ...
# 8792009665  2016-05-04      1  11552534115
# 8792009665  2016-05-04      1  11552534115
# 8792009665  2016-05-04      1  11552534115
# 8792009665  2016-05-04      1  11552534115
# 8792009665  2016-05-04      1  11552534115
#
# [188521 rows x 3 columns]

# %%
data5=pd.read_csv('cleaned_minutes_steps1.csv',index_col=0)

# %%
data5
# Out:
#             Steps00  Steps01  Steps02  Steps03  Steps04  Steps05  Steps06  \
# Id
# 1503960366        4       16        0        0        0        9        0
# 1503960366        0        0        0        0        0        0        0
# 1503960366        0        0        0        0        0        0        0
# 1503960366        0        0        0        0        0        0        0
# 1503960366        0        0        0        0        0        0        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 8877689391        0        0        0        0        0        0        0
# 8877689391        0        0        0        0        0        0        0
# 8877689391        0        0        0        0        0        0        0
# 8877689391        0        0        0        0        0        0        0
# 8877689391       35       21       44        0        6        0        0
#
#             Steps07  Steps08  Steps09  ...  Steps52  Steps53  Steps54  \
# ...

# %%
import dask.dataframe as dd

# %%
ddf1 = dd.from_pandas(data5, npartitions=10)  # Adjust the number of partitions as needed
ddf2 = dd.from_pandas(data4, npartitions=10)

# %%
final_dask = dd.merge(ddf1, ddf2, how='inner', left_on=['Id', 'date'], right_on=['Id', 'date'])

# %%
final=pd.merge(data1,data3,how='inner',left_on=['Id', 'date','time'],right_on=['Id', 'date','time'])

# %%
final
# Out:
#             Intensity00  Intensity01  Intensity02  Intensity03  Intensity04  \
# Id
# 1503960366            1            1            0            0            0
# 1503960366            0            0            0            0            0
# 1503960366            0            0            0            0            0
# 1503960366            0            0            0            0            0
# 1503960366            0            0            0            0            0
# ...                 ...          ...          ...          ...          ...
# 8877689391            0            0            0            0            0
# 8877689391            0            0            0            0            0
# 8877689391            0            0            0            0            0
# 8877689391            0            0            0            0            0
# 8877689391            1            1            1            0            1
#
# ...

# %%
final1=pd.merge(final,data4,how='inner',left_on=['Id', 'date'],right_on=['Id', 'date'])

# %%
final1
# Out:
#             Intensity00  Intensity01  Intensity02  Intensity03  Intensity04  \
# Id
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# ...                 ...          ...          ...          ...          ...
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
#
# ...

# %%
final_last=pd.merge(final1,data5,how='inner',left_on=['Id', 'date','time'],right_on=['Id', 'date','time'])

# %%
final_last
# Out:
#             Intensity00  Intensity01  Intensity02  Intensity03  Intensity04  \
# Id
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# 1503960366            1            1            0            0            0
# ...                 ...          ...          ...          ...          ...
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
# 8792009665            0            0            0            0            0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.lineplot(x='Steps54', y='Id', data=final_last)
plt.show()

# %%
g = sns.lmplot(
data=final_last,
    x="Calories58", y="Calories57", hue="Calories59",
    height=8
)
